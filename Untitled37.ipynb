# %% [markdown]
# <a href="https://colab.research.google.com/github/srinivasulu-2026/my-first-repo/blob/main/Untitled37.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Attempt 1: Store everything as a NumPy array
data = np.array([
    ["Alice",   20, 88.5, "A"],
    ["Bob",     21, 73.0, "B"],
    ["Charlie", 19, 91.0, "A"],
    ["Diana",   22, 65.5, "C"]
])

print(data)
print(data.dtype)
# Out:
# [['Alice' '20' '88.5' 'A']
#  ['Bob' '21' '73.0' 'B']
#  ['Charlie' '19' '91.0' 'A']
#  ['Diana' '22' '65.5' 'C']]
# <U32

# %%
# !pip3 install pandas

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
scores = pd.Series([88.5, 73.0, 91.0, 65.5])
print(scores)
# Out:
# 0    88.5
# 1    73.0
# 2    91.0
# 3    65.5
# dtype: float64

# %%
scores = pd.Series([88.5, 73, 91.0, 65.5])
print(scores)
# Out:
# 0    88.5
# 1    73.0
# 2    91.0
# 3    65.5
# dtype: float64

# %%
print(scores[0])
# Out:
# 88.5

# %%
scores = pd.Series(
    [88.5, 73.0, 91.0, 65.5],
    index=["Alice", "Bob", "Charlie"]
)
print(scores)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_17130/3939755777.py in <cell line: 0>()
# ----> 1 scores = pd.Series(
#       2     [88.5, 73.0, 91.0, 65.5],
#       3     index=["Alice", "Bob", "Charlie"]
#       4 )
#       5 print(scores)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     573             index = default_index(len(data))
#     574         elif is_list_like(data):
# --> 575             com.require_length_match(data, index)
#     576
#     577         # create/copy the manager
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     571     """
#     572     if len(data) != len(index):
# --> 573         raise ValueError(
#     574             "Length of values "
#     575             f"({len(data)}) "
#
# ...

# %%
print(scores["Bob"])
# Out:
# Bob    73.0
# Bob    65.5
# dtype: float64

# %%
print(type(scores))
# Out:
# <class 'pandas.core.series.Series'>

# %%
scores = pd.Series({
    "Alice":   88.5,
    "Bob":     73.0,
    "Charlie": 91.0,
    "Diana":   65.5
})
print(scores)
# Out:
# Alice      88.5
# Bob        73.0
# Charlie    91.0
# Diana      65.5
# dtype: float64

# %%
print(scores["Bob"])
# Out:
# 73.0

# %%
scores = pd.Series({"Alice": 88.5, "Bob": 73.0, "Charlie": 91.0})

# %%
print(scores.values)
# Out:
# [88.5 73.  91. ]

# %%
print(scores.index)
# Out:
# Index(['Alice', 'Bob', 'Charlie'], dtype='object')

# %%
import pandas as pd

data = {
    "Name":  ["Alice", "Bob", "Charlie", "Diana"],
    "Age":   [20, 21, 19, 22],
    "Score": [88.5, 73.0, 91.0, 65.5],
    "Grade": ["A", "B", "A", "C"]
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Score Grade
# 0    Alice   20   88.5     A
# 1      Bob   21   73.0     B
# 2  Charlie   19   91.0     A
# 3    Diana   22   65.5     C

# %%
print(df)
# Out:
#       Name  Age  Score Grade
# 0    Alice   20   88.5     A
# 1      Bob   21   73.0     B
# 2  Charlie   19   91.0     A
# 3    Diana   22   65.5     C

# %%
data = [
    {"Name": "Alice",   "Age": 20, "Score": 88.5},
    {"Name": "Bob",     "Age": 21, "Score": 73.0},
    {"Name": "Charlie", "Age": 19, "Score": 91.0},
]
df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Score
# 0    Alice   20   88.5
# 1      Bob   21   73.0
# 2  Charlie   19   91.0

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import numpy as np

arr = np.array([
    [20, 88.5],
    [21, 73.0],
    [19, 91.0]
])

print(arr)
# Out:
# [[20.  88.5]
#  [21.  73. ]
#  [19.  91. ]]

# %%
df = pd.DataFrame(arr)
df
# Out:
#       0     1
# 0  20.0  88.5
# 1  21.0  73.0
# 2  19.0  91.0

# %%
df = pd.DataFrame(arr, columns = ["Age", "Score"])
df
# Out:
#     Age  Score
# 0  20.0   88.5
# 1  21.0   73.0
# 2  19.0   91.0

# %%
data = {
    "Name":  ["Alice", "Bob", "Charlie", "Diana"],
    "Age":   [20, 21, 19, 22],
    "Score": [88.5, 73.0, 91.0, 65.5],
    "Grade": ["A", "B", "A", "C"]
}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Score Grade
# 0    Alice   20   88.5     A
# 1      Bob   21   73.0     B
# 2  Charlie   19   91.0     A
# 3    Diana   22   65.5     C

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(df.shape)
# Out:
# (4, 4)

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Score', 'Grade'], dtype='object')

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
print(df.dtypes)
# Out:
# Name      object
# Age        int64
# Score    float64
# Grade     object
# dtype: object
