# %% [markdown]
# What is the difference between hardware and software? Give one example of each.
#
# Hardware refers to the physical components of a computer system, while software is the set of instructions, data, or programs used to operate computers and execute specific tasks.
#
# Hardware example: A computer mouse (a physical input device).
# Software example: A web browser like Google Chrome (a program that allows you to access and view websites).
